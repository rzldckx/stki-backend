# %% [markdown]
# ## Load Dataset & Explore Data

# %%
import pandas as pd

data_file = 'data/data.csv'
df = pd.read_csv(data_file)
df.head()
# Out:
#    id source                                              title  \
# 0  83  tempo  Depo Plumpang Terbakar, Anggota DPR Minta Pert...
# 1  84  tempo  Jokowi Perintahkan Wapres Ma'ruf Amin Tinjau L...
# 2  85  tempo  HNW Mendukung Jamaah Umroh First Travel Dapatk...
# 3  86  tempo  Tim Dokkes Polri Telah Terima 14 Kantong Jenaz...
# 4  87  tempo  Bamsoet Ajak Komunitas Otomotif Kembangkan Per...
#
#                                                image  \
# 0  https://statik.tempo.co/data/2023/03/04/id_118...
# 1  https://statik.tempo.co/data/2023/03/04/id_118...
# 2  https://statik.tempo.co/data/2023/03/04/id_118...
# 3  https://statik.tempo.co/data/2023/03/04/id_118...
# 4  https://statik.tempo.co/data/2023/03/04/id_118...
#
#                                                  url  \
# 0  https://nasional.tempo.co/read/1698528/depo-pl...
# 1  https://nasional.tempo.co/read/1698522/jokowi-...
# 2  https://nasional.tempo.co/read/1698527/hnw-men...
# ...

# %%
# Cek nullable
df.isnull().sum()
# Out:
# id              0
# source          0
# title           0
# image         160
# url             0
# content       441
# date            0
# embedding       0
# created_at      0
# updated_at      0
# summary        10
# dtype: int64

# %%
# Data imputation
df = df.dropna()

# Cek nullable
df.isnull().sum()
# Out:
# id            0
# source        0
# title         0
# image         0
# url           0
# content       0
# date          0
# embedding     0
# created_at    0
# updated_at    0
# summary       0
# dtype: int64

# %%
# Cek jumlah kata dalam setiap fitur
df['title_word_count'] = df['title'].apply(lambda x: len(str(x).split()))
df['content_word_count'] = df['content'].apply(lambda x: len(str(x).split()))
df['summary_word_count'] = df['summary'].apply(lambda x: len(str(x).split()))

df[['title_word_count', 'content_word_count', 'summary_word_count']].describe()
# Out:
#        title_word_count  content_word_count  summary_word_count
# count      32127.000000        32127.000000        32127.000000
# mean          10.280667          320.368102           62.012762
# std            2.262694          162.844141           14.873269
# min            2.000000           11.000000           11.000000
# 25%            9.000000          216.000000           52.000000
# 50%           10.000000          291.000000           63.000000
# 75%           12.000000          387.000000           73.000000
# max           22.000000         1895.000000          139.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Visualisasi histogram
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.hist(df['title_word_count'], bins=20, color='blue', edgecolor='black')
plt.title('Jumlah Kata dalam Judul Berita')
plt.xlabel('Jumlah Kata')
plt.ylabel('Frekuensi')

plt.subplot(1, 3, 2)
plt.hist(df['content_word_count'], bins=20, color='green', edgecolor='black')
plt.title('Jumlah Kata dalam Isi Berita (Content)')
plt.xlabel('Jumlah Kata')
plt.ylabel('Frekuensi')

plt.subplot(1, 3, 3)
plt.hist(df['summary_word_count'], bins=20, color='red', edgecolor='black')
plt.title('Jumlah Kata dalam Summary')
plt.xlabel('Jumlah Kata')
plt.ylabel('Frekuensi')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dengan melakukan eksplorasi data dan pembersihan data dapat disimpulkan bahwa
# - Terdapat 32.127 berita dalam dataset ini.
# - Rata-rata terdapat judul dengan panjang 10 kata.
# - Rata-rata isi berita memiliki panjang 320 kata.
# - Rata-rata ringkasan berita terdiri dari 62 kata.

# %% [markdown]
# ## Preprocessing Text

# %%
# Pilih fitur yang merepresentasikan judul dan isi berita saja
news_data = df[['content']]

news_data.head()
# Out:
#                                              content
# 0  TEMPO.CO, Jakarta - Anggota Komisi VII DPR RI ...
# 1  TEMPO.CO, Jakarta - Presiden Joko Widodo atau ...
# 2  INFO NASIONAL - Wakil Ketua MPR RI Dr. H. M. H...
# 3  TEMPO.CO, Jakarta - Tim Kedokteran dan Kesehat...
# 4  INFO NASIONAL - Ketua MPR RI sekaligus Ketua U...

# %%
# Case-folding (lowercase) dan stop words removal
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('indonesian'))

def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Remove stopwords
    text = ' '.join([word for word in text.split() if word not in stop_words])
    return text

news_data['cleaned_text'] = news_data['content'].apply(preprocess_text)

news_data['cleaned_text'].head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hafid\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\hafid\AppData\Local\Temp\ipykernel_5236\465187285.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_data['cleaned_text'] = news_data['content'].apply(preprocess_text)
# 0    tempo.co, jakarta - anggota komisi vii dpr ri ...
# 1    tempo.co, jakarta - presiden joko widodo jokow...
# 2    info nasional - wakil ketua mpr ri dr. h. m. h...
# 3    tempo.co, jakarta - tim kedokteran kesehatan (...
# 4    info nasional - ketua mpr ri ketua ikatan moto...
# Name: cleaned_text, dtype: object

# %%
# TF-IDF Vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=1000)
X = vectorizer.fit_transform(news_data['cleaned_text'])

# %% [markdown]
# ## Modeling

# %%
# Menentukan jumlah cluster optimal menggunakan metode Elbow
from sklearn.cluster import KMeans

inertia = []
K = range(1, 11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# Plot metode Elbow
plt.figure(figsize=(8, 4))
plt.plot(K, inertia, 'bo-')
plt.xlabel('Jumlah cluster (k)')
plt.ylabel('Inertia')
plt.title('Metode Elbow untuk Menentukan k Optimal')
plt.show()

# %%
# Clustering dengan K-Means
from sklearn.cluster import KMeans

num_clusters = 9
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
news_data['cluster'] = kmeans.fit_predict(X)
# Out:
# C:\Users\hafid\AppData\Local\Temp\ipykernel_5236\1875915743.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_data['cluster'] = kmeans.fit_predict(X)

# %%
# Visualisasi Word Cloud untuk setiap cluster
from wordcloud import WordCloud
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 3, figsize=(15, 15))
axes = axes.flatten()

for cluster in range(num_clusters):
    cluster_text = ' '.join(news_data[news_data['cluster'] == cluster]['cleaned_text'])
    wordcloud = WordCloud(width=600, height=320, background_color='white').generate(cluster_text)

    ax = axes[cluster]
    ax.imshow(wordcloud, interpolation='bilinear')
    ax.axis('off')
    ax.set_title(f'Cluster {cluster}')

# Hapus subplot yang tidak terpakai
for i in range(num_clusters, len(axes)):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %%
# Memasukkan hasil clustering ke dalam DataFrame
df['cluster'] = news_data['cluster']

df.head()
# Out:
#    id source                                              title  \
# 0  83  tempo  Depo Plumpang Terbakar, Anggota DPR Minta Pert...
# 1  84  tempo  Jokowi Perintahkan Wapres Ma'ruf Amin Tinjau L...
# 2  85  tempo  HNW Mendukung Jamaah Umroh First Travel Dapatk...
# 3  86  tempo  Tim Dokkes Polri Telah Terima 14 Kantong Jenaz...
# 4  87  tempo  Bamsoet Ajak Komunitas Otomotif Kembangkan Per...
#
#                                                image  \
# 0  https://statik.tempo.co/data/2023/03/04/id_118...
# 1  https://statik.tempo.co/data/2023/03/04/id_118...
# 2  https://statik.tempo.co/data/2023/03/04/id_118...
# 3  https://statik.tempo.co/data/2023/03/04/id_118...
# 4  https://statik.tempo.co/data/2023/03/04/id_118...
#
#                                                  url  \
# 0  https://nasional.tempo.co/read/1698528/depo-pl...
# 1  https://nasional.tempo.co/read/1698522/jokowi-...
# 2  https://nasional.tempo.co/read/1698527/hnw-men...
# ...

# %%
# Menampilkan preview judul berita dari tiap cluster
num_clusters = df['cluster'].nunique()

for cluster in range(num_clusters):
    print(f"Cluster {cluster}:")
    cluster_news = df[df['cluster'] == cluster]['title'].head(5).tolist()
    for i, news in enumerate(cluster_news, 1):
        print(f"{i}. {news}")
    print("\n")
# Out:
# Cluster 0:
# 1. Dugaan Pencucian Uang Rafael Alun, PPATK Blokir Pihak Yang Diduga Terlibat, KPK Fokus Mencari Pidana Korupsi
# 2. Harta Rafael Alun Dianggap Tak Wajar, Pegiat Antikorupsi Singgung Soal Lemahnya Penanganan Illicit Enrichment
# 3. KPK Akan Periksa Eko Darmanto Selasa 7 Maret 2023
# 4. LHKPN Banyak Kekurangan, Eks Komisioner KPK: Akibat Kelemahan Hukum
# 5. Terbongkar! PNS Pajak Wahono Saputro Kongsi Erat Rafael
#
#
# Cluster 1:
# 1. Depo Plumpang Terbakar, Anggota DPR Minta Pertamina Pastikan Pasokan BBM Tak Terganggu
# 2. Jokowi Perintahkan Wapres Ma'ruf Amin Tinjau Lokasi Kebakaran Depo Plumpang
# 3. HNW Mendukung Jamaah Umroh First Travel Dapatkan Haknya
# 4. Bamsoet Ajak Komunitas Otomotif Kembangkan Perekonomian Nasional
# 5. Korban Tewas Kebakaran Depo Plumpang 17 Orang, Wapres Ma'ruf Amin: Semua Ditanggung Pertamina
#
#
# Cluster 2:
# 1. 14 Tahun Berkarya, PT SMI Siap Bangun Indonesia Berkelanjutan
# ...

# %%
# Tentukan nama kategori berdasarkan hasil word cloud
category_names = {
    0: "Hukum",
    1: "News",
    2: "Ekonomi",
    3: "Ekonomi",
    4: "Politik",
    5: "News",
    6: "Keuangan",
    7: "Keuangan",
    8: "Internasional"
}

# Tambahkan nama kategori ke dalam dataframe
df['category'] = df['cluster'].map(category_names)

# Tampilkan beberapa contoh artikel dengan kategori
df[['title', 'summary', 'content', 'category']].head()
# Out:
#                                                title  \
# 0  Depo Plumpang Terbakar, Anggota DPR Minta Pert...
# 1  Jokowi Perintahkan Wapres Ma'ruf Amin Tinjau L...
# 2  HNW Mendukung Jamaah Umroh First Travel Dapatk...
# 3  Tim Dokkes Polri Telah Terima 14 Kantong Jenaz...
# 4  Bamsoet Ajak Komunitas Otomotif Kembangkan Per...
#
#                                              summary  \
# 0  Anggota Komisi VII DPR RI Rofik Hananto menyay...
# 1  Presiden Joko Widodo telah memerintahkan Wakil...
# 2  Wakil Ketua MPR RI Dr. H. M. Hidayat Nur Wahid...
# 3  Tim Kedokteran dan Kesehatan (Dokkes) Polri te...
# 4  Ketua MPR RI Bambang Soesatyo telah diangkat s...
#
#                                              content category
# 0  TEMPO.CO, Jakarta - Anggota Komisi VII DPR RI ...     News
# 1  TEMPO.CO, Jakarta - Presiden Joko Widodo atau ...     News
# 2  INFO NASIONAL - Wakil Ketua MPR RI Dr. H. M. H...     News
# 3  TEMPO.CO, Jakarta - Tim Kedokteran dan Kesehat...     News
# ...

# %%
# Ekspor data ke CSV
final_features = df[['id', 'title', 'summary', 'content', 'category', 'date', 'image', 'source', 'url']]

output_path = "data/news.csv"
final_features.to_csv(output_path, index=False)

print(f'Data berhasil diekspor ke {output_path}')
# Out:
# Data berhasil diekspor ke data/news.csv
